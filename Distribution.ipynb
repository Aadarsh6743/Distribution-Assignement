# %% [markdown]
# 1. Simulate 30 rolls with =RANDBETWEEN(1,6). What is the probability of rolling a 3 exactly 5 times? (Hint: Use
# BINOM.DIST)
#
#  Ans- Step-by-Step Solution
#      1. Understand the scenario:
#
# Rolling a fair die → probability of any face = 1/6.
#
# Number of trials (rolls) = 𝑛=30.
#
# Success = rolling a 3.
#
# Probability of success =  𝑝=16.
#
# We want exactly 𝑘 = 5 successes.
#
#   2.Apply the Binomial Distribution formula:
#      p(X=K) = (n/k)*p^k*(1-P)^n-k
#
#      Substituting values
#
#      p(X=5)= (30/5)*(1/6)^5*(5/6)^25
#
#      Excel Formula:
#
#       Use: =BINOM.DIST(5,30,1/6,FALSE)
#       FALSE → exact probability (not cumulative)
#
#       4.Interpretation:
#
#         This gives the probability of rolling a 3 exactly 5 times in 30 rolls.
#
#          Numerically, it comes out to about 0.186 (≈ 18.6%).
#
#
#
#       Final Answer: The probability is ≈ 18.6%.
#        In Excel: =BINOM.DIST(5,30,1/6,FALSE)

# %% [markdown]
# 4.What is the concept of standardization (z-score), and why is it important in data analysis? Explain the
# formula and how standardization transforms a dataset
#
# Ans-  Concept of Standardization (Z-Score)
# Standardization means converting raw data values into a common scale (z-scores).
#
# A z-score tells you how many standard deviations a value is away from the mean.
#
# This makes datasets comparable, even if they have different units or scales.
#     Formula:
#       Z=x-u/σ
#
#    Where:
#
#    𝑥= data value
#
#    𝜇= mean of dataset
#
#    𝜎= standard deviation of dataset
#
# How Standardization Transforms a Dataset
# After transformation:
#
# Mean becomes 0
#
# Standard deviation becomes 1
#
# This allows you to:
#
# Compare values across different datasets.
#
# Use algorithms (like regression, clustering, PCA) that require normalized data.
#
# Identify outliers easily (z-scores far from 0).

# %% [markdown]
# 5.What is Kurtosis and their type?
#
#      Ans- Kurtosis is a statistical measure that describes the shape of a distribution’s tails compared to a normal distribution.
#
# It tells us whether data has more or fewer extreme values (outliers) than expected in a normal distribution.
#
# In simple words: kurtosis shows how “peaked” or “flat” a distribution is, and how heavy or light the tails are.
#
#   Types of Kurtosis
# Mesokurtic (≈ 0):
#
# Distribution similar to the normal curve.
#
# Moderate tails, neither heavy nor light.
#
# Example: Standard normal distribution.
#
# Leptokurtic (> 0):
#
# Distribution with heavy tails and a sharper peak.
#
# More extreme values/outliers than normal.
#
# Example: Stock market returns often show leptokurtic behavior.
#
# Platykurtic (< 0):
#
# Distribution with light tails and a flatter peak.
#
# Fewer extreme values than normal.
#
# Example: Uniform distribution.

# %% [markdown]
# 6.Explain why the uniform distribution is a good model for the outcome of rolling a fair die.
#
#      Ans-Why Uniform Distribution Fits a Fair Die
#         Equal Probability:
#         A fair die has 6 faces (1–6), and each face has the same chance of appearing:
#         𝑃(any face)=1/6
#
#         This matches the definition of a uniform distribution, where all outcomes are equally likely.
#
# Discrete Uniform Distribution:
#
# Unlike continuous uniform (values between 0 and 1), a die is discrete — only integers 1 through 6.
#
# The probability distribution is flat: every outcome has the same height in a probability histogram.
#
# No Bias:
# Since the die is fair, there’s no preference for any number. This lack of skew makes the uniform distribution the perfect model.
#
# Intuition
# If you roll the die many times and plot the frequencies of 1, 2, 3, 4, 5, 6 → the bars will be roughly equal in height.
#
# That “flatness” is exactly what the uniform distribution represents.

# %% [markdown]
# 8.How does log transformation help in stabilizing variance and making data more normally distributed?
#
# Ans- What is Log Transformation?
# A log transformation means applying the logarithm (usually natural log, ln) to each data value.
#
# Example: If your dataset is
# [𝑥1,𝑥2,𝑥3,…], after transformation it becomes
# [ln(𝑥1),ln⁡(𝑥2),ln(𝑥3),…].
#
# It’s often used in data analysis when values are skewed or when variance increases with the mean.
#
# *How It Helps*
# Stabilizing Variance (Reducing Heteroscedasticity):
#
# In many datasets (like income, sales, biological measurements), larger values tend to have larger variance.
#
# Log transformation compresses large values more than small ones.
#
# This reduces the spread and makes variance more consistent across the dataset.
#
# 👉 Example: Raw incomes (₹10,000 vs ₹1,00,000) differ hugely, but after log transformation, the difference shrinks, making analysis fairer.
#
# 2.Making Data More Normally Distributed:
#
# Many real-world datasets are right-skewed (long tail of large values).
#
# Log transformation pulls in those extreme values, reducing skewness.
#
# The distribution often becomes closer to a bell curve (normal distribution), which is ideal for statistical tests and models.
#
# 3.Improving Statistical Modeling:
#
# Many statistical methods (like regression, ANOVA, t-tests) assume normality and equal variance.
#
# Log transformation helps meet these assumptions, making results more reliable.
#
# It also makes multiplicative relationships easier to analyze as additive ones.
